# %% [markdown]
# # Comparing Encoder-Decoders Analysis

# %% [markdown]
# ### Model Architecture

# %%
report_files = ["/Users/bking/IdeaProjects/LanguageModelRNN/experiment_results/encdec_noing10_200_512_04drb/encdec_noing10_200_512_04drb.json", "/Users/bking/IdeaProjects/LanguageModelRNN/experiment_results/encdec_noing10_bow_200_512_04drb/encdec_noing10_bow_200_512_04drb.json"]
log_files = ["/Users/bking/IdeaProjects/LanguageModelRNN/experiment_results/encdec_noing10_200_512_04drb/encdec_noing10_200_512_04drb_logs.json", "/Users/bking/IdeaProjects/LanguageModelRNN/experiment_results/encdec_noing10_bow_200_512_04drb/encdec_noing10_bow_200_512_04drb_logs.json"]
reports = []
logs = []
import json
import matplotlib.pyplot as plt
import numpy as np

for report_file in report_files:
    with open(report_file) as f:
        reports.append((report_file.split('/')[-1].split('.json')[0], json.loads(f.read())))
for log_file in log_files:
    with open(log_file) as f:
        logs.append((log_file.split('/')[-1].split('.json')[0], json.loads(f.read())))
        
for report_name, report in reports:
    print '\n', report_name, '\n'
    print 'Encoder: \n', report['architecture']['encoder']
    print 'Decoder: \n', report['architecture']['decoder']
# Out:
# encdec_noing10_200_512_04drb
#
# Encoder:
# nn.Sequential {
#   [input -> (1) -> (2) -> (3) -> (4) -> output]
#   (1): nn.LookupTable
#   (2): nn.Dropout(0.400000)
#   (3): nn.LSTM(200 -> 512)
#   (4): nn.Dropout(0.400000)
# }
# Decoder:
# nn.gModule
#
# encdec_noing10_bow_200_512_04drb
#
# Encoder:
# nn.Sequential {
#   [input -> (1) -> (2) -> (3) -> (4) -> output]
#   (1): nn.LookupTable
#   (2): nn.Mean
#   (3): nn.Linear(200 -> 512)
#   (4): nn.Replicate
# }
# Decoder:
# nn.gModule

# %% [markdown]
# ### Perplexity on Each Dataset

# %%
# %matplotlib inline
from IPython.display import HTML, display

def display_table(data):
    display(HTML(
        u'<table><tr>{}</tr></table>'.format(
            u'</tr><tr>'.join(
                u'<td>{}</td>'.format('</td><td>'.join(unicode(_) for _ in row)) for row in data)
            )
    ))

def bar_chart(data):
    n_groups = len(data)
    
    train_perps = [d[1] for d in data]
    valid_perps = [d[2] for d in data]
    test_perps = [d[3] for d in data]
    
    fig, ax = plt.subplots(figsize=(10,8))
    
    index = np.arange(n_groups)
    bar_width = 0.3

    opacity = 0.4
    error_config = {'ecolor': '0.3'}

    train_bars = plt.bar(index, train_perps, bar_width,
                     alpha=opacity,
                     color='b',
                     error_kw=error_config,
                     label='Training Perplexity')

    valid_bars = plt.bar(index + bar_width, valid_perps, bar_width,
                     alpha=opacity,
                     color='r',
                     error_kw=error_config,
                     label='Valid Perplexity')
    test_bars = plt.bar(index + 2*bar_width, test_perps, bar_width,
                     alpha=opacity,
                     color='g',
                     error_kw=error_config,
                     label='Test Perplexity')

    plt.xlabel('Model')
    plt.ylabel('Scores')
    plt.title('Perplexity by Model and Dataset')
    plt.xticks(index + bar_width / 3, [d[0] for d in data])
    plt.legend()

    plt.tight_layout()
    plt.show()

data = [['<b>Model</b>', '<b>Train Perplexity</b>', '<b>Valid Perplexity</b>', '<b>Test Perplexity</b>']]

for rname, report in reports:
    data.append([rname, report['train_perplexity'], report['valid_perplexity'], report['test_perplexity']])

display_table(data)
bar_chart(data[1:])
# Out:
# <table><tr><td><b>Model</b></td><td><b>Train Perplexity</b></td><td><b>Valid Perplexity</b></td><td><b>Test Perplexity</b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td>2.36730175651</td><td>715.007688611</td><td>868.108036068</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td>1.7752875281</td><td>858.775111277</td><td>1154.4081424</td></tr></table>

# %% [markdown]
# ### Loss vs. Epoch

# %%
# %matplotlib inline
plt.figure(figsize=(10, 8))
for rname, l in logs:
    for k in l.keys():
        plt.plot(l[k][0], l[k][1], label=str(k) + ' ' + rname + ' (train)')
        plt.plot(l[k][0], l[k][2], label=str(k) + ' ' + rname + ' (valid)')
plt.title('Loss v. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Perplexity vs. Epoch

# %%
# %matplotlib inline
plt.figure(figsize=(10, 8))
for rname, l in logs:
    for k in l.keys():
        plt.plot(l[k][0], l[k][3], label=str(k) + ' ' + rname + ' (train)')
        plt.plot(l[k][0], l[k][4], label=str(k) + ' ' + rname + ' (valid)')
plt.title('Perplexity v. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Perplexity')
plt.legend()
plt.show()

# %% [markdown]
# ### Generations

# %%
def print_sample(sample, best_bleu=None):
    enc_input = ' '.join([w for w in sample['encoder_input'].split(' ') if w != '<pad>'])
    gold = ' '.join([w for w in sample['gold'].split(' ') if w != '<mask>'])
    print('Input: '+ enc_input + '\n')
    print('Gend: ' + sample['generated'] + '\n')
    print('True: ' + gold + '\n')
    if best_bleu is not None:
        cbm = ' '.join([w for w in best_bleu['best_match'].split(' ') if w != '<mask>'])
        print('Closest BLEU Match: ' + cbm + '\n')
        print('Closest BLEU Score: ' + str(best_bleu['best_score']) + '\n')
    print('\n')
    
def display_sample(samples, best_bleu=False):
    for enc_input in samples:
        data = []
        for rname, sample in samples[enc_input]:
            gold = ' '.join([w for w in sample['gold'].split(' ') if w != '<mask>'])
            data.append([rname, '<b>Generated: </b>' + sample['generated']])
            if best_bleu:
                cbm = ' '.join([w for w in sample['best_match'].split(' ') if w != '<mask>'])
                data.append([rname, '<b>Closest BLEU Match: </b>' + cbm + ' (Score: ' + str(sample['best_score']) + ')'])
        data.insert(0, ['<u><b>' + enc_input + '</b></u>', '<b>True: ' + gold+ '</b>'])
        display_table(data)

def process_samples(samples):
    # consolidate samples with identical inputs
    result = {}
    for rname, t_samples, t_cbms in samples:
        for i, sample in enumerate(t_samples):
            enc_input = ' '.join([w for w in sample['encoder_input'].split(' ') if w != '<pad>'])
            if t_cbms is not None:
                sample.update(t_cbms[i])
            if enc_input in result:
                result[enc_input].append((rname, sample))
            else:
                result[enc_input] = [(rname, sample)]
    return result

# %%
samples = process_samples([(rname, r['train_samples'], r['best_bleu_matches_train'] if 'best_bleu_matches_train' in r else None) for (rname, r) in reports])
display_sample(samples, best_bleu='best_bleu_matches_train' in reports[1][1])
# Out:
# <table><tr><td><u><b> yakitori 焼き鳥</b></u></td><td><b>True:  1 place the almond flour , salt , and butter into an electric beater with a paddle attachment and <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> strawberry shortcakes</b></u></td><td><b>True:  combine coconut , flour , salt . <step> add milk and vanilla . <step> i find it much easier to use <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> combine the cornmeal , flour , sugar , baking powder , and salt , mixing well . <step> add the milk , and bread crumbs</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> combine the cornmeal , flour , sugar , mustard , baking powder and salt , mixing well . <step> add the milk , egg <end> (Score: 70.1611656261)</td></tr></table>
# <table><tr><td><u><b> michelle 's baked ham</b></u></td><td><b>True:  to prepare the garlic sauce , heat the vegetable oil , garlic , and parsley over medium heat until warmed through . set aside to</b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> huevos rancheros</b></u></td><td><b>True:  combine rice with 1 c water . <step> boil and simmer 15 minutes . <step> remove from heat . <step> add <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> gnocchi alla romana</b></u></td><td><b>True:  beat eggs with water ; season with salt and pepper . set aside . spray an 8 - inch omelet pan or nonstick skillet <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> tomato soup with white beans and pasta</b></u></td><td><b>True:  preheat oven to 400 . pierce potatoes several times with a fork . transfer to a large baking dish and cook <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium heat . add the onion ,</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large pot over medium heat cook and stir <end> (Score: 64.7285941823)</td></tr></table>
# <table><tr><td><u><b> pico de gallo and guacamole</b></u></td><td><b>True:  instructions heat a teaspoon of coconut oil in a casserole pot or a large saucepan . add the lamb and stir it <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> 5 - minute healthy strawberry frozen yogurt</b></u></td><td><b>True:  preheat oven to 350 <step> brown beef in skillet & add taco seasoning . cook as directed on seasoning packet <step> spray an <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium heat . add the onion ,</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large pot over medium heat cook and stir <end> (Score: 64.7285941823)</td></tr></table>
# <table><tr><td><u><b> rajma ( kidney bean curry )</b></u></td><td><b>True:  preheat oven to 350f ° ( 180c ° ) . <step> cut tomatoes in half and remove seeds . <step> brush with <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> amazing watermelon greek salad with feta</b></u></td><td><b>True:  combine the first 6 ingredients and shape into patties . <step> cook patties in a large skillet over medium - low heat 20 <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> 1 . heat oil in a large skillet over medium heat . add the onion , and cook over medium - low heat for 20</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> heat oil in a large skillet over medium heat . add the onion , corn and soy beans , and cook <end> (Score: 55.6126655011)</td></tr></table>
# <table><tr><td><u><b> perfect baked rice with herbs and veggies</b></u></td><td><b>True:  preheat oven to 350 degrees . <step> cut up waffles into bite size pieces . think of them as croutons and that is <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> grilled pizza with no - cook tomato sauce</b></u></td><td><b>True:  heat 1 tbsp . oil in a large skillet over medium - high heat . add runner beans and swiss chard <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> 1 . heat oil in a large skillet over medium heat . add the onion , and cook over medium - low heat for 20</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> heat oil in a large skillet over medium heat . add the onion , corn and soy beans , and cook <end> (Score: 55.6126655011)</td></tr></table>
# <table><tr><td><u><b> curry chickpea salad</b></u></td><td><b>True:  preheat oven to 375 degrees . lightly grease donut pans ( this one is my favorite <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium heat . add the onion ,</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large pot over medium heat cook and stir <end> (Score: 64.7285941823)</td></tr></table>
# <table><tr><td><u><b> coffee cake in a mug with cinnamon oatmeal struesel topping</b></u></td><td><b>True:  to make the apple - cranberry relish : peel , core , and chop the apples into 1 / 4 - inch <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> to make the apple - cranberry relish : peel , core , and chop the apples into 1 / 4 - inch - inch -</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> to make the apple - cranberry relish : peel , core , and chop the apples into 1 / 4 - inch <end> (Score: 83.6360058744)</td></tr></table>

# %%
samples = process_samples([(rname, r['valid_samples'], r['best_bleu_matches_valid'] if 'best_bleu_matches_valid' in r else None) for (rname, r) in reports])
display_sample(samples, best_bleu='best_bleu_matches_valid' in reports[1][1])
# Out:
# <table><tr><td><u><b> <UNK2> <mask> <mask> <mask> <mask> <mask> <UNK2> <mask> <UNK2> <mask></b></u></td><td><b>True:  1 . medaillons waschen , trockentupfen und in mundgerechte st ? cke schneiden . zucchini waschen , putzen <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> <mask> <mask> <mask> <mask> <mask> <mask> <mask> <mask> <mask> <mask></b></u></td><td><b>True:  in a food processor , pulse 1 bun until fine crumbs form ( you should have about 1 / 4 cup ) <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> 1 . heat oil in a large skillet over medium heat . add the onion , and cook over medium - low heat for 20</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> heat oil in a large skillet over medium heat . add the onion , corn and soy beans , and cook <end> (Score: 55.6126655011)</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> <UNK2> <mask> <mask> <mask> <UNK2> <mask> <UNK2> <mask> <UNK2> <mask></b></u></td><td><b>True:  stir together flour , cocoa powder , sugar , salt and baking powder . add eggs , milk and vanilla . stir until dry <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> 1 . heat oil in a large skillet over medium heat . add the onion , and cook over medium - low heat for 20</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> heat oil in a large skillet over medium heat . add the onion , corn and soy beans , and cook <end> (Score: 55.6126655011)</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> 1 . heat oil in a large skillet over medium heat . add the onion , and cook over medium - low heat for 20</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> heat oil in a large skillet over medium heat . add the onion , corn and soy beans , and cook <end> (Score: 55.6126655011)</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> <UNK2> <UNK2> <UNK2> <UNK2> <UNK2> <UNK2> <UNK2> <UNK2> <UNK2> <UNK2></b></u></td><td><b>True:  preheat oven to 375º f . <step> grease a donut pan and set aside . <step> in a large bowl whisk together flour <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> 1 . heat oil in a large skillet over medium heat . add the onion , and cook over medium - low heat for 20</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> heat oil in a large skillet over medium heat . add the onion , corn and soy beans , and cook <end> (Score: 55.6126655011)</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> 1 . heat oil in a large skillet over medium heat . add the onion , and cook over medium - low heat for 20</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> heat oil in a large skillet over medium heat . add the onion , corn and soy beans , and cook <end> (Score: 55.6126655011)</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> 1 . heat oil in a large skillet over medium heat . add the onion , and cook over medium - low heat for 20</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> heat oil in a large skillet over medium heat . add the onion , corn and soy beans , and cook <end> (Score: 55.6126655011)</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> 1 . heat oil in a large skillet over medium heat . add the onion , and cook over medium - low heat for 20</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> heat oil in a large skillet over medium heat . add the onion , corn and soy beans , and cook <end> (Score: 55.6126655011)</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>

# %%
samples = process_samples([(rname, r['test_samples'], r['best_bleu_matches_test'] if 'best_bleu_matches_test' in r else None) for (rname, r) in reports])
display_sample(samples, best_bleu='best_bleu_matches_test' in reports[1][1])
# Out:
# <table><tr><td><u><b> perfect porterhouse steak</b></u></td><td><b>True:  place steak on a plate and coat lightly with olive oil . rub steak with meat tenderizer . sprinkle <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> in a large saucepan , combine the ice , garlic , and cashews in a large bowl . add the milk and stir it until</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> in a large saucepan , combine the water , lentils , carrot , onion , garlic , and bay <end> (Score: 31.3482066596)</td></tr></table>
# <table><tr><td><u><b> mediterranean sandwich</b></u></td><td><b>True:  mix the olive oil and balsamic vinegar . set aside . <step> cook the chicken breast and cut into strips . <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees . <step> cut up waffles into bite size pieces . think of them as croutons and that is is is</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees . <step> cut up waffles into bite size pieces . think of them as croutons and that is <end> (Score: 87.7277201636)</td></tr></table>
# <table><tr><td><u><b> charbroiled oysters from dragos</b></u></td><td><b>True:  heat the grill to med - high . <step> melt butter with garlic and pepper in a large <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium heat . add the onion ,</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large pot over medium heat cook and stir <end> (Score: 64.7285941823)</td></tr></table>
# <table><tr><td><u><b> chocolate mousse , french style</b></u></td><td><b>True:  place chocolate in a heatproof bowl and melt over a pot of simmering water . remove from heat and set aside . bring cream to</b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> peanut butter jelly ice cream</b></u></td><td><b>True:  to make the jelly <step> simply blend the strawberries , sweetner and chia seeds together until thick and smooth . leave to the side for</b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> coconut curried shrimp</b></u></td><td><b>True:  in a small , heavy saucepan , bring the rice and 1 1 / 2 cups water to a <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> heat oil in a large skillet over medium heat . add the onion , and cook over medium - low heat for 20 20 minutes</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> heat oil in a large skillet over medium heat . add the onion , corn and soy beans , and cook <end> (Score: 55.6126655011)</td></tr></table>
# <table><tr><td><u><b> tasty green bean casserole</b></u></td><td><b>True:  preheat the oven to 325 degrees f ( 165 degrees c ) . <step> fry bacon in a skillet over medium - high <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium heat . add the onion ,</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large pot over medium heat cook and stir <end> (Score: 64.7285941823)</td></tr></table>
# <table><tr><td><u><b> butternut squash risotto</b></u></td><td><b>True:  combine 2 cups squash and 2 1 / 2 cups water in a saucepan ; bring to a boil . reduce <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> dutch baby pancake</b></u></td><td><b>True:  preheat oven to 425 degrees . in a medium cast - iron or ovenproof nonstick skillet , melt 2 tablespoons butter <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> chili dog casserole</b></u></td><td><b>True:  preheat oven to 350 degrees f ( 175 degrees c ) . <step> lightly grease a 9x13 inch baking dish . <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> mac - n - cheese pizza</b></u></td><td><b>True:  preheat oven to 400 degrees f ( 200 degrees c ) . spray a 10x15 - inch baking sheet with cooking spray . <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium heat . add the onion ,</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large pot over medium heat cook and stir <end> (Score: 64.7285941823)</td></tr></table>
# <table><tr><td><u><b> bbq baby back ribs - pressure cooker</b></u></td><td><b>True:  place the metal rack in your cooker and add 1 / 2 cup of water ( <end></b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium heat . add the onion ,</td></tr><tr><td>encdec_noing10_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large pot over medium heat cook and stir <end> (Score: 64.7285941823)</td></tr></table>
# <table><tr><td><u><b> prime rib</b></u></td><td><b>True:  1 . the night before cooking , liberally season the prime rib with the salt and <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>
# <table><tr><td><u><b> chatpata indian maggi recipe !</b></u></td><td><b>True:  1 ) boil the noodles and drain it . 2 ) heat oil in a pan and add <end></b></td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Generated: </b> <beg> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet over medium - high heat . add runner</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td><b>Closest BLEU Match: </b> preheat oven to 350 degrees f ( 175 degrees c ) . <step> in a large skillet <end> (Score: 63.1660821942)</td></tr></table>

# %% [markdown]
# ### BLEU Analysis

# %%
def print_bleu(blue_structs):
    data= [['<b>Model</b>', '<b>Overall Score</b>','<b>1-gram Score</b>','<b>2-gram Score</b>','<b>3-gram Score</b>','<b>4-gram Score</b>']]
    for rname, blue_struct in blue_structs:
        data.append([rname, blue_struct['score'], blue_struct['components']['1'], blue_struct['components']['2'], blue_struct['components']['3'], blue_struct['components']['4']])
    display_table(data)

# %%
# Training Set BLEU Scores
print_bleu([(rname, report['train_bleu']) for (rname, report) in reports])
# Out:
# <table><tr><td><b>Model</b></td><td><b>Overall Score</b></td><td><b>1-gram Score</b></td><td><b>2-gram Score</b></td><td><b>3-gram Score</b></td><td><b>4-gram Score</b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td>27.34</td><td>45.6</td><td>28.6</td><td>23.8</td><td>18</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td>5.1</td><td>21.4</td><td>8.6</td><td>3</td><td>1.2</td></tr></table>

# %%
# Validation Set BLEU Scores
print_bleu([(rname, report['valid_bleu']) for (rname, report) in reports])
# Out:
# <table><tr><td><b>Model</b></td><td><b>Overall Score</b></td><td><b>1-gram Score</b></td><td><b>2-gram Score</b></td><td><b>3-gram Score</b></td><td><b>4-gram Score</b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td>0</td><td>17</td><td>3.4</td><td>0.6</td><td>0</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td>4.59</td><td>17.6</td><td>6.9</td><td>3</td><td>1.2</td></tr></table>

# %%
# Test Set BLEU Scores
print_bleu([(rname, report['test_bleu']) for (rname, report) in reports])
# Out:
# <table><tr><td><b>Model</b></td><td><b>Overall Score</b></td><td><b>1-gram Score</b></td><td><b>2-gram Score</b></td><td><b>3-gram Score</b></td><td><b>4-gram Score</b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td>8.06</td><td>30.2</td><td>12.6</td><td>6</td><td>1.9</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td>10.36</td><td>25.3</td><td>10.3</td><td>7.1</td><td>6.2</td></tr></table>

# %%
# All Data BLEU Scores
print_bleu([(rname, report['combined_bleu']) for (rname, report) in reports])
# Out:
# <table><tr><td><b>Model</b></td><td><b>Overall Score</b></td><td><b>1-gram Score</b></td><td><b>2-gram Score</b></td><td><b>3-gram Score</b></td><td><b>4-gram Score</b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td>13.25</td><td>31</td><td>14.9</td><td>10.1</td><td>6.6</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td>6.94</td><td>21.4</td><td>8.6</td><td>4.4</td><td>2.9</td></tr></table>

# %% [markdown]
# ### N-pairs BLEU Analysis
#
# This analysis randomly samples 1000 pairs of generations/ground truths and treats them as translations, giving their BLEU score. We can expect very low scores in the ground truth and high scores can expose hyper-common generations

# %%
# Training Set BLEU n-pairs Scores
print_bleu([(rname, report['n_pairs_bleu_train']) for (rname, report) in reports])
# Out:
# <table><tr><td><b>Model</b></td><td><b>Overall Score</b></td><td><b>1-gram Score</b></td><td><b>2-gram Score</b></td><td><b>3-gram Score</b></td><td><b>4-gram Score</b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td>35.39</td><td>46.1</td><td>34.8</td><td>31.6</td><td>31</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td>100</td><td>100</td><td>100</td><td>100</td><td>100</td></tr></table>

# %%
# Validation Set n-pairs BLEU Scores
print_bleu([(rname, report['n_pairs_bleu_valid']) for (rname, report) in reports])
# Out:
# <table><tr><td><b>Model</b></td><td><b>Overall Score</b></td><td><b>1-gram Score</b></td><td><b>2-gram Score</b></td><td><b>3-gram Score</b></td><td><b>4-gram Score</b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td>100</td><td>100</td><td>100</td><td>100</td><td>100</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td>100</td><td>100</td><td>100</td><td>100</td><td>100</td></tr></table>

# %%
# Test Set n-pairs BLEU Scores
print_bleu([(rname, report['n_pairs_bleu_test']) for (rname, report) in reports])
# Out:
# <table><tr><td><b>Model</b></td><td><b>Overall Score</b></td><td><b>1-gram Score</b></td><td><b>2-gram Score</b></td><td><b>3-gram Score</b></td><td><b>4-gram Score</b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td>43.11</td><td>52.3</td><td>44.3</td><td>40.3</td><td>37</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td>100</td><td>100</td><td>100</td><td>100</td><td>100</td></tr></table>

# %%
# Combined n-pairs BLEU Scores
print_bleu([(rname, report['n_pairs_bleu_all']) for (rname, report) in reports])
# Out:
# <table><tr><td><b>Model</b></td><td><b>Overall Score</b></td><td><b>1-gram Score</b></td><td><b>2-gram Score</b></td><td><b>3-gram Score</b></td><td><b>4-gram Score</b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td>51.97</td><td>59.9</td><td>51.7</td><td>49.3</td><td>47.8</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td>100</td><td>100</td><td>100</td><td>100</td><td>100</td></tr></table>

# %%
# Ground Truth n-pairs BLEU Scores
print_bleu([(rname, report['n_pairs_bleu_gold']) for (rname, report) in reports])
# Out:
# <table><tr><td><b>Model</b></td><td><b>Overall Score</b></td><td><b>1-gram Score</b></td><td><b>2-gram Score</b></td><td><b>3-gram Score</b></td><td><b>4-gram Score</b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td>7.59</td><td>25.7</td><td>11</td><td>5.3</td><td>2.2</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td>4.37</td><td>23.7</td><td>7</td><td>2.7</td><td>0.8</td></tr></table>

# %% [markdown]
# ### Alignment Analysis
#
# This analysis computs the average Smith-Waterman alignment score for generations, with the same intuition as N-pairs BLEU, in that we expect low scores in the ground truth and hyper-common generations to raise the scores

# %%
def print_align(reports):
    data= [['<b>Model</b>', '<b>Average (Train) Generated Score</b>','<b>Average (Valid) Generated Score</b>','<b>Average (Test) Generated Score</b>','<b>Average (All) Generated Score</b>', '<b>Average (Gold) Score</b>']]
    for rname, report in reports:
        data.append([rname, report['average_alignment_train'], report['average_alignment_valid'], report['average_alignment_test'], report['average_alignment_all'], report['average_alignment_gold']])
    display_table(data)

print_align(reports)
# Out:
# <table><tr><td><b>Model</b></td><td><b>Average (Train) Generated Score</b></td><td><b>Average (Valid) Generated Score</b></td><td><b>Average (Test) Generated Score</b></td><td><b>Average (All) Generated Score</b></td><td><b>Average (Gold) Score</b></td></tr><tr><td>encdec_noing10_200_512_04drb</td><td>42.380952381</td><td>112</td><td>54.4761904762</td><td>57.8952380952</td><td>20.2</td></tr><tr><td>encdec_noing10_bow_200_512_04drb</td><td>119</td><td>119</td><td>119</td><td>119</td><td>14.7238095238</td></tr></table>
